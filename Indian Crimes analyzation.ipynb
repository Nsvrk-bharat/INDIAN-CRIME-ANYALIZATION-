# %% [markdown]
# #   TOPIC  :-
# # <font color= '#33ccff'>" CRIMES</font> IN <font color='#33ccff'> INDIA"</font>
#
#
# # <font color= '#FA5858'>Analysis</font> is <font color='#FA5858'>done by</font>
#
# # --<font color= '#FFD700'>N</font>.<font color= '#FF1493'>S</font>.<font color= '#FFD700'>V</font>.<font color= '#FF1493'>R</font>.<font color= '#FFD700'>K</font> <font color='#FFD700'>BHARAT</font> (<font color='#33ccff'>CSE</font>) b-tech
#
# # ---<font color= '#8904B1'>201801270001</font>

# %% [markdown]
# # Datasets are ;-

# %% [markdown]
# ###                                'crime(2017-2020)'.,
# <a href= "#1.-Data-for-crime-happend-in-timespan-of-2017-2020:"> CRIMES IN INDIA</a>

# %% [markdown]
# ###                                'registered crimes(2018 & 2019)'.,
# <a href= "#2.-Data-of-Crimes-Registered-in-the-year-2018-2019"> REGISTERED CRIMES</a>

# %% [markdown]
# ###                                'violent crimes(2020)'.,
# <a href= "#3.-Data-of-violent-crimes-recorded-in-2020"> VIOLENT CRIMES RECORDED </a>

# %% [markdown]
# ###                               'juvenile crimes (2018,2019,2020)'.,
# <a href= "#4.-Data-of-juvenile-crimes-commited-in-(2017,2018,2020)"> JUVENILE CRIMES COMMITED </a>

# %% [markdown]
# ###                               'cyber crime(2018,2019,2020)'.,
# <a href= "#5.-Data-of-cyber-crimes-for-the-years-in-(2018,2019,2020)"> CYBER CRIMES IN 2018,19,20</a>

# %% [markdown]
# ###                               'crime against children(2018,2019,2020)'.,
# <a href= "#6.-Data-of-cases-about-violence-against-children-in-years(2018,2019,2020)"> CRIMES AGAINST CHILDREN </a>

# %% [markdown]
# ###                                'seized currency'.,
# <a href= "#7.-Data-of-seized-currency-in-the-year-2020"> SEIZED CURRENCY</a>

# %% [markdown]
# <a href= "#key-points-:">key points and conclusion</a>

# %% [markdown]
# ## <font color= '#F7819F'>All</font> <font color= '#33ccff'>Datasets</font> are <font color= '#F7819F'>taken</font> from <font color= '#33ccff'>online</font>( <font color= '#FF1493'>source</font> = <font color= '#FFD700'>kaggle</font>)

# %% [markdown]
# #  Basic <font color= '#FF1493'>analysis</font> form the <font color= '#A52A2A'>data</font>:
# ## 1.Ploting <font color= '#FF4500'>crime cases happened in 2017</font> state wise.
# ## 2.Which state has <font color= '#FF8C00'>highest rape cases</font> in violent crimes
# ## 3.Understanding <font color= '#32CD32'>Type if crimes happened</font> in the year 2018
# ## 4.The <font color= '#C71585'>Percentage Share of Arrestees</font> under Each Crime During 2019
# ## 5.<font color= '#A52A2A'>Violent(total) crime data</font> of different states of india
# ## 6.The states which have more <font color= '#00CED1'>cyber cases</font>
# ## 7.<font color= '#B8860B'>Crimes against children</font>Crimes against children in 2020
# ## 8.<font color= '#8B008B'>Juvenile & heinous crimes</font>Juvenile& heinous crimes in  india
# ## 9.<font color= '#0000CD'>cyber cases</font>  for 2020
# ## 10.Over all juvenile <font color= '#FF1493'>crime rate</font> crime rate
# ## 11.seized currency - <font color= '#00FF00'>Denomination of 2000 & 1000</font>

# %% [markdown]
# # <font color= '#006400'>Libraries</font> to be <font color= '#4682B4'>installed</font> and <font color= '#F4A460'>imported</font>:

# %%
import pandas as pd 
## pip install pandas
import matplotlib.pyplot as plt
## pip install matplotlib.pyplot 
import seaborn as sns
## pip install seaborn

# %% [markdown]
# ## 1. Data for crime happend in timespan of 2017-2020:

# %% [markdown]
# ![crime.jfif](attachment:crime.jfif)

# %% [markdown]
# ![crime-in-india-2019.png](attachment:crime-in-india-2019.png)

# %%
#1,0#CRIMES HAPPENED FROM (2017-2020)
import matplotlib as plt
import pandas as pd
A= pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime(2017-2020).csv')
A
# Out:
#     Unnamed: 0 STATE NAME  CRIME (2017)  CRIME (2018)  CRIME (2019)  \
# 0            0         AP        114604        110693        106774
# 1            1        ARP          2843          2968          2534
# 2            2         AS         94337        103616        102250
# 3            3         BH        177595        176973        164163
# 4            4         CH         58200        562624         55029
# 5            5         GO          4466          3074          2692
# 6            6         GU        131385        126935        147122
# 7            7         HP         14160         14007         13386
# 8            8        J&K         23848         23583         24501
# 9            9         KA        137338        138847        148402
# 10          10         KR        206789        257074        260097
# 11          11         MP        272423        268614        264418
# 12          12        MAH        249834        275414        261714
# ...

# %%
#1.1#bargraph
    #state wise crimes happened in india in the year 2017...USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
A= pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime(2017-2020).csv')
A
x =A["STATE NAME"]
y =A["CRIME (2018)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.bar(x,y)
plt.show()

# %%
#1.2#linegraph
    #state wise crimes happened in india in the year 2019...USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
A= pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime(2017-2020).csv')
A
x = A["STATE NAME"]
y = A["CRIME (2019)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.plot(x,y)
plt.show()

# %%
#1.3#Donut
   #understanding the crime rate for four years...,USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
labels =A["STATE NAME"]
donut= A["CRIME RATE"]

plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.pie(donut,labels=labels)
round=plt.Circle((0,0),0.6,color='white')
p=plt.gcf()
p.gca().add_artist(round)
plt.legend()
plt.show()

# %%
#1.4#COLOUR Bargraph 
   #PRESENTING THE CRIME HAPPENED IN THE YEAR 2019,USING SEABORN LIB
import seaborn as sns
sns.barplot(A['STATE NAME'],A['CRIME (2019)'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='STATE NAME', ylabel='CRIME (2019)'>

# %%
#1.5#DISTPLOT
    #SHOWING THE CRIME USING DISTPLOT FOR THE YEAR 2017...USING SEABORNLIB
import seaborn as sns
sns.distplot(A['CRIME (2017)'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CRIME (2017)', ylabel='Density'>

# %%
#1.6#JOINTPLOT
    #SHOWING THE GRAP OF YEARS (2017)&(2019)..,USING SEABORNLIB
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
A= pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime(2017-2020).csv')
A
sns.jointplot(A['CRIME (2017)'],A['CRIME (2019)'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#1.7#JOINTPLOT
     #SHOWING THE CRIME DATA OF THE YEARS 2018,2019...USING SEABORN WITH KDE
sns.jointplot(A['CRIME (2018)'],A['CRIME (2019)'],kind="kde")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#1.8#PAIRGRAPH
     #SHOWING THE CRIME DATA OF THE YEARS 2017,2018,2019 AND CRIME PER (STATE),CRIME RATE...USING SEABORN 
A= pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime(2017-2020).csv')
A
sns.pairplot(A[['CRIME (2017)','CRIME (2018)','CRIME (2019)','CRIME PER SHARE (STATE)','CRIME RATE']])

# %% [markdown]
# [<a href= "#Datasets-are-;-">Back To Top</a>]

# %% [markdown]
# ## 2. Data of Crimes Registered in the year 2018-2019

# %% [markdown]
# ![OIP%20%281%29.jfif](attachment:OIP%20%281%29.jfif)

# %%
#2.0#CRIMES THAT happened IN YEARS(2018-19)
import matplotlib as plt
import pandas as pd
B = pd.read_csv(r'c:\users\hp\onedrive\desktop\registered crimes(2018 & 2019).csv')
B
# Out:
#                                       CRIME HEAD  in year 2018  in year 2019  \
# 0                                       1 Murder         69320         62159
# 1                     2 Attempt to Commit Murder         86153         93937
# 2    3 Culpable Homicide not Amounting to Murder          7135          6486
# 3          4 Attempt to Commit Culpable Homicide          7226          9895
# 4                                         5 Rape        144579        130446
# 5                       6 Kidnapping & Abduction        165252         73557
# 6                           7 Unnatural Offences          1279          1491
# 7                                      8 Dacoity         18418         16487
# 8                                      9 Robbery         51312         46899
# 9                   10Criminal Trespass/Burglary         90503         79379
# 10                                      11 Theft        259441        222556
# ...

# %%
#2.1#BARGRAPH
    #UNDERSTANDING TYPE OF CRIMES HAPPENED IN THE YEAR 2018...,USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
B = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\registered crimes(2018 & 2019).csv')
B
x = B["CRIME HEAD"]
y = B["in year 2018"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.barh(x,y)
plt.show()

# %%
#2.2#LINEGRAPH
    #UNDERSTANDING TYPE OF CRIMES HAPPENED IN THE YEAR 2019...,USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
B = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\registered crimes(2018 & 2019).csv')
B

x = B["CRIME HEAD"]
y = B["in year 2019"]
plt.figure(figsize=(6,6),dpi =100,facecolor='w',edgecolor='k')
plt.plot(y,x)
plt.show()

# %%
#2.3#DONUT
    #UNDERSTANDING The Percentage Share of Arrestees under Each Crime During 2019..USING MATPLOTLIB 
import pandas as pd
import matplotlib.pyplot as plt
B = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\registered crimes(2018 & 2019).csv')
B

x = B["CRIME HEAD"]
donut = B["Percentage Share of Arrestees under Each Crime During 2019"]

plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.pie(donut,labels=x)
round=plt.Circle((0,0),0.6,color='white')
p=plt.gcf()
p.gca().add_artist(round)

plt.show()

# %%
#2.4#COLORED BARGRAPH
    #PLOTING GRAPH USING SEABORN FOR THE YEAR 2018
import seaborn as sns
sns.barplot(B['in year 2018'],B['CRIME HEAD'])   
plt.figure(figsize=(7,7),dpi =100,facecolor='w',edgecolor='k')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#2.5#DISTPLOT
    #SHOWING THE CRIME USING DISTPLOT FOR THE YEAR 2017...USING SEABORNLIB
import seaborn as sns
import pandas as pd
B = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\registered crimes(2018 & 2019).csv')
B
sns.distplot(B['in year 2019'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='in year 2019', ylabel='Density'>

# %%
#2.6#JOINTPLOT
    #COMPARISION OF VIOLENT (ARSON)&VIOLENT (RIOT)..,USING SEABORNLIB
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

B = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\registered crimes(2018 & 2019).csv')
B
sns.jointplot(B["in year 2018"],B["in year 2019"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#3.7#JOINTPLOT WITH HEX
    #PLOTING GRAPH  OF JUVENILE CRIME FOR YEARS 2017,2018..USING SEABORLIB WITH HEX 
sns.jointplot(B["in year 2019"],B["Percentage Share of Arrestees under Each Crime During 2019"],kind="kde")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#2.8#PAIR OF GRAPHS
    #PLOTING THE GRAPH FOR THE YEARS(2018,2019),PERCENTAGE VARIATION IN 2019 OVER 2018,PERCENTAGE SHARE OF ARRESTEES UNDER EACH CRIME DURING 2019..USING SEABORNLIB
import pandas as pd
import seaborn as sns
B = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\registered crimes(2018 & 2019).csv')
B
sns.pairplot(B[['in year 2018','in year 2019','Percentage Variation in 2019 Over 2018','Percentage Share of Arrestees under Each Crime During 2019']])

# %% [markdown]
# [<a href= "#Datasets-are-;-">Back To Top</a>]

# %% [markdown]
# ## 3. Data of violent crimes recorded in 2020

# %% [markdown]
# ![OIP%20%282%29.jfif](attachment:OIP%20%282%29.jfif)

# %% [markdown]
# ![OIP%20%283%29.jfif](attachment:OIP%20%283%29.jfif)

# %%
#3.0#VIOLEMT CRIMES OF INDIA
import pandas as pd
import matplotlib.pyplot as plt
C = pd.read_csv(r'c:\users\hp\onedrive\desktop\violent crimes(2020).csv')
C
# Out:
#     Unnamed: 0 STATE NAME  VIOLENT (MURDER)  VIOLENT (CULPABLE HOMICIDE)  \
# 0            0         AP              1123                           83
# 1            1        ARP                46                            6
# 2            2        ASS              1149                           34
# 3            3         BI              2581                          150
# 4            4         CH               957                           37
# 5            5         GO                30                           12
# 6            6         GU              1120                           73
# 7            8         HP               101                            3
# 8            9        J&K               142                           22
# 9           11         KN              1573                           77
# 10          12         KR               305                          132
# 11          13         MP              2004                          136
# ...

# %%
#3.1#BARGRAPH
    #PLOTING GRAPH FOR VIOLENT(TOTAL) CRIME DATA OF DIFFERENT STATES OF INDIA..USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
C = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\violent crimes(2020).csv')
C
x = C["STATE NAME"]
y = C["VIOLENT TOTAL"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.bar(x,y)
plt.show()

# %%
#3.2#LINEGRAPH
    #PLOTING GRAPH FOR VIOLENT(MURDER) CRIME DATA OF DIFFERENT STATES IN INDIA..USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
C = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\violent crimes(2020).csv')
C
x = C["STATE NAME"]
y = C["VIOLENT (MURDER)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.plot(x,y)

plt.show()

# %%
#3.3#PIE CHART
    #VIOLENT (ATTEMPT TO MURDER) CRIMES OF DIFFERENT STATES IN INDIAS ..,USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
C = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\violent crimes(2020).csv')
C
x = C["STATE NAME"]
donut = C["VIOLENT (ATTEMPT TO MURDER)"]

plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.pie(donut,labels=x)
round=plt.Circle((0,0),0.6,color='white')
p=plt.gcf()
p.gca().add_artist(round)

plt.show()

# %%
#3.4#COLOURED BARGRAPH
    #SHOWING THE DATA OF VIOLENT (KIDNAPPING & ABDUCTION) CRIMES IN DIFFERENT STATES OF INDIA..., USING SEABORNLIB
import seaborn as sns
import pandas as pd
C = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\violent crimes(2020).csv')
C
sns.barplot(C["STATE NAME"],C["VIOLENT (KIDNAPPING & ABDUCTION)"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='STATE NAME', ylabel='VIOLENT (KIDNAPPING & ABDUCTION)'>

# %%
#3.5#DISTANCE GRAPH
    #PLOTING THE GRAPH FOR VIOLENT (ARSON) CRIME DATA ..USING SEABORNLIB
C = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\violent crimes(2020).csv')
C
sns.distplot(C["VIOLENT (ARSON)"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='VIOLENT (ARSON)', ylabel='Density'>

# %%
#3.6#JOINTPLOT
    #COMPARISION OF VIOLENT (ARSON)&VIOLENT (RIOT)..,USING SEABORNLIB
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

C = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\violent crimes(2020).csv')
C
sns.jointplot(C["VIOLENT (RIOT)"],C["VIOLENT (ROBERY)"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#3.7#JOINTPLOT WITH HEX
    #PLOTING GRAPH  OF JUVENILE CRIME FOR YEARS 2017,2018..USING SEABORLIB WITH HEX 
sns.jointplot(C["VIOLENT (ATTEMPT TO MURDER)"],C["VIOLENT (KIDNAPPING & ABDUCTION)"],kind="kde")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#3.8#PAIR OF GRAPHS
    #COMPARISION OF THE GRAPH FOR VIOLENT (KIDNAPPING & ABDUCTION),(ATTEMPT TO MURDER),(RAPE)..USING SEABORNLIB
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
C = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\violent crimes(2020).csv')
C

sns.pairplot(C[["VIOLENT (MURDER)","VIOLENT (KIDNAPPING & ABDUCTION)","VIOLENT (RAPE)","VIOLENT (RIOT)","VIOLENT (ROBERY)","VIOLENT TOTAL"]])

# %% [markdown]
# [<a href= "#Datasets-are-;-">Back To Top</a>]

# %% [markdown]
# ## 4. Data of juvenile crimes commited in (2017,2018,2020)

# %% [markdown]
# ![images1.png](attachment:images1.png)

# %% [markdown]
# ![OIP%20%284%29.jfif](attachment:OIP%20%284%29.jfif)

# %% [markdown]
# ![OIP%20%285%29.jfif](attachment:OIP%20%285%29.jfif)

# %%
#4.0#JUVENILE CRIME IN YEARS(2017,2018&2019) OF INDIA
import pandas as pd
import matplotlib.pyplot as plt
D = pd.read_csv(r'c:\users\hp\onedrive\desktop\juvenile crimes(2018,2019,2020).csv')
D
# Out:
#     Unnamed: 0 STATE NAME  JUVENILE CRIME (2018)  JUVENILE CRIME (2019)  \
# 0            0         AP                    883                   1015
# 1            1        ARP                     81                     66
# 2            2        ASS                    487                    624
# 3            3         BI                   4371                   1658
# 4            4         CH                   1691                   1914
# 5            5         GO                     64                     28
# 6            6         GU                   4380                   1577
# 7            7         HR                   1041                   1098
# 8            8         HP                    272                    195
# 9            9        J&K                    102                    181
# 10          10         ND                   1969                   2366
# 11          11         KN                    412                    446
# ...

# %%
#4.1#BARGRAPH
    #PLOTING GRAPH FOR JUVENILE CRIME DATA OF THE YEAR 2018..USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
D = pd.read_csv(r'c:\users\hp\onedrive\desktop\juvenile crimes(2018,2019,2020).csv')
D
x = D["STATE NAME"]
y = D["JUVENILE CRIME (2019)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.bar(x,y)
plt.show()

# %%
#4.2#LINEGRAPH
    #PLOTING GRAPH FOR JUVENILE CRIME DATA OF THE YEAR 2017..USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
D = pd.read_csv(r'c:\users\hp\onedrive\desktop\juvenile crimes(2018,2019,2020).csv')
D
x = D["STATE NAME"]
y = D["JUVENILE CRIME (2018)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.plot(x,y)
plt.show()

# %%
#4.3#DONUT GRAPH
    #PLOTING GRAPH FOR JUVENILE CRIME DATA OF THE YEAR 2017..USING MATPLOTLIBimport pandas as pd
import matplotlib.pyplot as plt
D = pd.read_csv(r'c:\users\hp\onedrive\desktop\juvenile crimes(2018,2019,2020).csv')
D
x = D["STATE NAME"]
donut= D["JUVENILE CRIME (2020)"]

plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.pie(donut,labels=x)
round=plt.Circle((0,0),0.6,color='white')
p=plt.gcf()
p.gca().add_artist(round)
plt.legend()
plt.show()

# %%
#4.4#COLOURED BARGRAPH
    #SHOWING THE DATA OF JUVENILE CRIMES IN DIFFERENT STATES OF INDIA FOR THE YEAR 2017..., USING SEABORNLIB
import seaborn as sns
D = pd.read_csv(r'c:\users\hp\onedrive\desktop\juvenile crimes(2018,2019,2020).csv')
D
sns.barplot(D['STATE NAME'],D['JUVENILE CRIME (2019)'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='STATE NAME', ylabel='JUVENILE CRIME (2019)'>

# %%
#4.5#JOINTPLOT WITH KDE
    #PLOTING JOINT GRAPH WITH KDE FOR THE YEAR (2018,2019)..USING SEABORNLIB WITH KDE
import seaborn as sns    
D = pd.read_csv(r'c:\users\hp\onedrive\desktop\juvenile crimes(2018,2019,2020).csv')
D
sns.jointplot(D['JUVENILE CRIME (2019)'],D['JUVENILE CRIME (2020)'],kind="kde")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#4.6#JOINTPLOT
    #SHOWING THE GRAPH OF JUVENILE CRIME DATA IN YERARS 2017..,USING SEABORNLIB
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

D = pd.read_csv(r'c:\users\hp\onedrive\desktop\juvenile crimes(2018,2019,2020).csv')
D
sns.jointplot(D['JUVENILE CRIME (2018)'],D['JUVENILE CRIME (2020)'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#4.7#DISTANCE GRAPH
    #PLOTING THE GRAPH FOR THE YEAR 2019..USING SEABORNLIB
import seaborn as sns
D = pd.read_csv(r'c:\users\hp\onedrive\desktop\juvenile crimes(2018,2019,2020).csv')
D
sns.distplot(D['JUVENILE CRIME (2019)'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='JUVENILE CRIME (2019)', ylabel='Density'>

# %%
#4.8#PAIR OF GRAPHS
    #PLOTING THE GRAPH FOR THE YEARS(2018,2019)..USING SEABORNLIB
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
D = pd.read_csv(r'c:\users\hp\onedrive\desktop\juvenile crimes(2018,2019,2020).csv')
D

sns.pairplot(D[['JUVENILE CRIME (2018)','JUVENILE CRIME (2019)','JUVENILE CRIME (2020)','JUVENILE CRIME (PER SHARE)','JUVENILE CRIME (RATE)']])

# %% [markdown]
# [<a href= "#Datasets-are-;-">Back To Top</a>]

# %% [markdown]
# ## 5. Data of cyber crimes for the years in (2018,2019,2020)

# %% [markdown]
# ![OIP.jfif](attachment:OIP.jfif)

# %% [markdown]
# ![OIP%20%287%29.jfif](attachment:OIP%20%287%29.jfif)

# %% [markdown]
# ![OIP%20%286%29.jfif](attachment:OIP%20%286%29.jfif)

# %%
#5.0#CYBER CRIMES IN THE YEARS(2017,2018,2019) OF INDIA
import pandas as pd
import matplotlib.pyplot as plt
E = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\cyber crime(2018,2019,2020).csv')
E
# Out:
#     Unnamed: 0 STATE NAME  CYBER CRIME (2018)  CYBER CRIME (2019)  \
# 0            0         AP                 282                 536
# 1            1        ARP                  18                   6
# 2            2         AS                 379                 483
# 3            3         BI                 114                 242
# 4            4         CH                 123                 103
# 5            5         GO                  62                  17
# 6            6         GU                 227                 242
# 7            7         HR                 151                 224
# 8            8         HP                  38                  50
# 9            9         PN                 226                 149
# 10           9        J&K                  37                  34
# 11          10         KN                1020                1447
# 12          11         KR                 450                 290
# ...

# %%
#5.1#BAR GRAPH
    #STATE WISE CYBER CRIMES HAPPEND IN INDIA IN THE YEAR (2018)...USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
E = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\cyber crime(2018,2019,2020).csv')
E
x = E["STATE NAME"]
y = E["CYBER CRIME (2018)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.bar(x,y)
plt.show()

# %%
#5.2#LINE GRAPH
   #CYBER CRIMES HAPPEND IN YEAR 2019..,USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
E = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\cyber crime(2018,2019,2020).csv')
E
x = E["STATE NAME"]
y = E["CYBER CRIME (2019)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.plot(x,y)

plt.show()

# %%
#5.3#PIE CHART
    #CYBER CRIMES HAPPEND IN THE YEAR 2020..,USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
E = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\cyber crime(2018,2019,2020).csv')
E
x = E["STATE NAME"]
donut = E["CYBER CRIME (2020)"]

plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.pie(donut,labels=x)
round=plt.Circle((0,0),0.6,color='white')
p=plt.gcf()
p.gca().add_artist(round)
plt.legend()
plt.show()

# %%
#5.4#COLOURED BARGRAPH
    #SHOWING THE DATA OF JUVENILE CRIMES IN DIFFERENT STATES OF INDIA FOR THE YEAR 2018..., USING SEABORNLIB
import seaborn as sns
import pandas as pd
E = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\cyber crime(2018,2019,2020).csv')
E
sns.barplot(E["STATE NAME"],E["CYBER CRIME (2018)"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='STATE NAME', ylabel='CYBER CRIME (2018)'>

# %%
#5.5#DISTANCE GRAPH
    #PLOTING THE GRAPH FOR CYBER CRIME DATA IN THE YEAR 2020..USING SEABORNLIB
E = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\cyber crime(2018,2019,2020).csv')
E
sns.distplot(E["CYBER CRIME (2020)"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CYBER CRIME (2020)', ylabel='Density'>

# %%
#5.6#JOINTPLOT
    #SHOWING THE GRAPH OF JUVENILE CRIME DATA IN YERARS 2018&2020..,USING SEABORNLIB
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

E = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\cyber crime(2018,2019,2020).csv')
E
sns.jointplot(E["CYBER CRIME (2018)"],E["CYBER CRIME (2020)"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#5.7#JOINTPLOT WITH KDE
    #THIS GRAPH IS THE COMPARISON OF CYBER CRIME DATA IN (2018&2019) BETWEEN  YEARSimport seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
E = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\cyber crime(2018,2019,2020).csv')
E
sns.jointplot(E['CYBER CRIME (2018)'],E['CYBER CRIME (2019)'],kind="kde")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#5.8#PAIR OF GRAPHS
    #PLOTING THE GRAPH FOR THE YEARS(2018,2019,2020)..USING SEABORNLIB
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
E = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\cyber crime(2018,2019,2020).csv')
E

sns.pairplot(E[["CYBER CRIME (2018)","CYBER CRIME (2019)","CYBER CRIME (2020)","CYBER CRIME (PER SHARE)","CYBER CRIME (RATE)"]])

# %% [markdown]
# [<a href= "#Datasets-are-;-">Back To Top</a>]

# %% [markdown]
# ## 6. Data of cases about violence against children in years(2018,2019,2020)

# %% [markdown]
# ![download.jfif](attachment:download.jfif)

# %% [markdown]
# ![images.jfif](attachment:images.jfif)

# %%
#6#CRIMES AGAINST THE CHILDREN
import pandas as pd
import matplotlib.pyplot as plt
F = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime against children(2018,2019,2020).csv')
F
# Out:
#     Unnamed: 0 STATE NAME  CHILDREN CRIME (2018)  CHILDREN CRIME (2019)  \
# 0            0         AP                   2059                   1992
# 1            1        ARP                    134                    181
# 2            2        ASS                   1385                   2835
# 3            3         BI                   2255                   1917
# 4            4         CH                   4358                   4469
# 5            5         GO                    330                    242
# 6            6         GU                   3219                   3623
# 7            7         ND                   9350                   9489
# 8            8         HP                    467                    477
# 9            9        J&K                    211                    308
# 10          10         KN                   3416                   3961
# 11          11         KR                   2391                   2384
# ...

# %%
#6.1#BAR GRAPH
    #STATES WISE GRAPH ABOUT CRIMES HAPPENING AGAINST THE CHILDREN FOR YEARS (2017,2018,2019)...USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt

F = pd.read_csv(r'c:\Users\hp\OneDrive\Desktop\crime against children(2018,2019,2020).csv')

x = F["STATE NAME"]
y = F["CHILDREN CRIME (2018)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.bar(x,y)
plt.show()

# %%
#6.2#LINEGRAPH
    #PLOTING GRAPH FOR JUVENILE CRIME DATA OF THE YEAR 2017..USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
F = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime against children(2018,2019,2020).csv')
F
x = F["STATE NAME"]
y = F["CHILDREN CRIME (2019)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.plot(x,y)
plt.show()

# %%
#6.3#DONUT
    #SHOWING THE CHILDREN CRIME (PER SHARE IN DIFFERENT STATES..,USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
F = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime against children(2018,2019,2020).csv')
F
x = F["STATE NAME"]
donut= F["CHILDREN CRIME (RATE)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.pie(donut,labels=x)
round=plt.Circle((0,0),0.6,color='white')
p=plt.gcf()
p.gca().add_artist(round)
plt.legend()
plt.show()

# %%
#6.4#COLOURED BARGRAPH
    #SHOWING THE DATA OF THE CRIME AGAINST CHILDREN FORM YEARS (2017,2018,2019)..., USING SEABORNLIB
import seaborn as sns
import pandas as pd
F = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime against children(2018,2019,2020).csv')
F
sns.barplot(F["STATE NAME"],F["CHILDREN CRIME (2018)"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='STATE NAME', ylabel='CHILDREN CRIME (2018)'>

# %%
#6.5#DISTANCE GRAPH
    #PLOTING THE GRAPH THE CRIME AGAINST CHILDREN FORM YEARS (2017,2018,2019) CHILDREN CRIME(RATE) ..USING SEABORNLIB
F = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime against children(2018,2019,2020).csv')
F
sns.distplot(F["CHILDREN CRIME (RATE)"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CHILDREN CRIME (RATE)', ylabel='Density'>

# %%
#6,4.6#JOINTPLOT
    #SHOWING THE GRAPH OF CRIME AGAINST CHILDREN FORM YEARS (2017,2018,2019)..,USING SEABORNLIB
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
F = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime against children(2018,2019,2020).csv')
F
sns.jointplot(F["CHILDREN CRIME (PER SHARE)"],F["CHILDREN CRIME (RATE)"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#6.7#JOINTPLOT WITH KDE
    #THIS GRAPH IS THE CRIME AGAINST CHILDREN FORM YEARS (2017,2018)...USING SEABORN 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
F = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime against children(2018,2019,2020).csv')
sns.jointplot(F["CHILDREN CRIME (2018)"],F["CHILDREN CRIME (2019)"],kind="kde")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#6.8#PAIR OF GRAPHS
    #PLOTING THE GRAPH FOR CHILDREN CRIME OF YEARS (2018,2019,2020), CHILDREN CRIME (PER SHARE),CHILDREN CRIME(RATE)...USING SEABORNLIB
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
F = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\crime against children(2018,2019,2020).csv')
F

sns.pairplot(F[["CHILDREN CRIME (2019)","CHILDREN CRIME (2018)","CHILDREN CRIME (2020)","CHILDREN CRIME (PER SHARE)","CHILDREN CRIME (RATE)"]])

# %% [markdown]
# [<a href= "#Datasets-are-;-">Back To Top</a>]

# %% [markdown]
# ## 7. Data of seized currency in the year 2020

# %% [markdown]
# ![siezed%20currency.jfif](attachment:siezed%20currency.jfif)

# %% [markdown]
# ![images%20%283%29.jfif](attachment:images%20%283%29.jfif)

# %%
#7.0#SEIZED CURRENCY IN THE YEARS (2020)
import pandas as pd
import matplotlib.pyplot as plt
G = pd.read_csv(r'c:\users\hp\onedrive\desktop\seized currency (2020).csv')
G
# Out:
#     Unnamed: 0 STATE NAME  DENOMINATION - 2000  DENOMINATION - 1000  \
# 0            0         AP                    3                 5002
# 1            1        ARP                    3                    0
# 2            2        ASS                    0                  230
# 3            3         BI                    9                 2387
# 4            4         CH                    0                 1499
# 5            5         GO                   11                    9
# 6            6         GU                 1300                11706
# 7            7         ND                    0                28479
# 8            8         HP                    0                   26
# 9            9        J&K                    2                   14
# 10          10         KN                  254                 2291
# 11          11         KR                    2                 1585
# 12          12         MP                    8                  768
# ...

# %%
#7.1#BAR GRAPH
    #STATES WISE TOTAL SIEZED CURRENCY FOR YEARS 2020...USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
G = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\seized currency (2020).csv')
G
x = G["STATE NAME"]
y = G["TOTAL VALUE (IN RS.)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.bar(x,y)
plt.show()

# %%
#7.1#BAR GRAPH
    #STATES WISE TOTAL SIEZED CURRENCY FOR YEARS 2020...USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
G = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\seized currency (2020).csv')
G
x = G["STATE NAME"]
y = G["TOTAL VALUE (IN RS.)"]
plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.plot(x,y)
plt.show()

# %%
#7.3#DONUT
    #SHOWING THE DENOMINATION-1000  IN DIFFERENT STATES..,USING MATPLOTLIB
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
G = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\seized currency (2020).csv')
G
x = G["STATE NAME"]
donut = G["DENOMINATION - 1000"]

plt.figure(figsize=(8,8),dpi =100,facecolor='w',edgecolor='k')
plt.pie(donut,labels=x)
round=plt.Circle((0,0),0.6,color='white')
p=plt.gcf()
p.gca().add_artist(round)
plt.legend()
plt.show()

# %%
#7.4#COLOURED BARGRAPH
    #SHOWING THE DATA OF DENOMINATION OF 500 IN DIFFERENT STATES OF INDIA FOR THE YEAR 2020..., USING SEABORNLIB
import seaborn as sns
import pandas as pd
G = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\seized currency (2020).csv')
G
sns.barplot(G["STATE NAME"],G["DENOMINATION - 500"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='STATE NAME', ylabel='DENOMINATION - 500'>

# %%
#7.5#DISTANCE GRAPH
    #PLOTING THE GRAPH FOR DENOMINATION - 1000 FROM SIEZED CURRENCY IN THE YEAR 2020 DATA..USING SEABORNLIB
G = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\seized currency (2020).csv')
G
sns.distplot(G["DENOMINATION - 1000"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='DENOMINATION - 1000', ylabel='Density'>

# %%
#7.6#JOINTPLOT
    #SHOWING THE GRAPH OF COMPARISION OF 500 AND 1000 IN 2020..,USING SEABORNLIB
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

G = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\seized currency (2020).csv')
G
sns.jointplot(G["DENOMINATION - 500"],G["DENOMINATION - 1000"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#7.7#JOINTPLOT WITH KDE
    #THIS GRAPH IS THE COMPARISON OF DENOMINAATION OF 2000 AND 1000 DATA FOR YEAR (2020) BETWEEN DENOMINTION OF 2000&1000 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
G = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\seized currency (2020).csv')
G
sns.jointplot(G["DENOMINATION - 2000"],G["DENOMINATION - 1000"],kind="kde")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#7.8#PAIR OF GRAPHS
    #PLOTING THE GRAPH FOR THE DENOMINATIONS (2000,1000,500,50),TOTAL VALUE..USING SEABORNLIB
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
G = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\seized currency (2020).csv')
G

sns.pairplot(G[["DENOMINATION - 2000","DENOMINATION - 1000","DENOMINATION - 500","DENOMINATION - 100","DENOMINATION - 50","TOTAL VALUE (IN RS.)"]])

# %% [markdown]
# [<a href= "#Datasets-are-;-">Back To Top</a>]

# %% [markdown]
# # key points :
# ## -<font color= '#C71585'>Crimes</font> are classified into <font color= '#C71585'>sub</font>-<font color= '#C71585'>grouped</font> crimes
# ## -<font color= '#FF1493'>Women</font> <font color= '#FE2E64'>safty</font> is been a question mark'?' for past <font color= '#FF1493'>decade</font>...
# ## -<font color= '#FFD700'>Children</font> who are under age are been to <font color= '#FFD700'>work</font>, instead of <font color= '#DBA901'>studying</font>.
# ## -<font color= '#BA55D3'>Cyber attacks</font> are increasing, making </font><font color= '#BA55D3'>online treat</font> to <font color= '#BA55D3'>india</font>..
# ## -<font color= '#ADFF2F'>Per</font> day <font color= '#ADFF2F'>7000</font> new cases are being registered.
# ## -<font color= '#228B22'>Scames</font> and <font color= '#228B22'>frauds</font> are increased, targeting <font color= '#228B22'>middle class</font> and <font color= '#228B22'>lower middle class</font>..
# ## -<font color= '#FF0000'>Rape</font> cases are being completely <font color= '#FF0000'>ignored</font>,<font color= '#FF0000'>women safty</font> is less in <font color= '#FF0000'>northern states</font>...
# ## -<font color= '#FA8072'>Murder</font> cases are happening just because of <font color= '#FA8072'>hatered</font> and for <font color= '#FA8072'>pride</font>,<font color= '#FA8072'>money</font> or <font color= '#FA8072'>property</font>
# ## -Seized <font color= '#1E90FF'>currency</font> in the years 2020 & Comparing the <font color= '#1E90FF'> DENOMINATIONS</font> value of '<font color= '#1E90FF'>2000</font>','<font color= '#1E90FF'>1000</font>','<font color= '#1E90FF'>500</font>','<font color= '#1E90FF'>100</font>','<font color= '#1E90FF'>50</font>'

# %% [markdown]
# # conclusion:
# ## Crimes are kept on increasing evey year.
# ### -Crimes against <font color= '#FF1493'>Women</font>,<font color= '#FFD700'>children</font> should be controlled ,for that government should implement <font color= '#FF0000'>strict laws</font> and <font color= '#8904B1'>police monitering or patroling</font> should be active..
# ### -<font color= '#00BFFF'>Cyber crimes</font> and <font color= '#FF4500'>attacks</font> are also increased in latest year..
# ### -If the <font color= '#FF1493'>crime rate</font> is being increased ,then it effects the <font color= '#B8860B'>international image</font> and <font color= '#32CD32'>releations</font> ...
# ### -<font color= '#DC143C'>Toruist sector</font> will aslo get effected..
# ### -Life of an <font color= '#008080'>individual</font> will become more <font color= '#BDB76B'>degraded</font>..which will <font color= '#DC143C'>increases</font> in  more crime..
# ### -The <font color= '#FFD700'>economy</font> of <font color= '#20B2AA'>india</font> will completely <font color= '#FF00FF'>fall down</font>..
# ### -<font color= '#B22222'>Femines</font>,<font color= '#FA8072'>shortage</font> of daily goods,<font color= '#C71585'>infilation</font>,<font color= '#228B22'>unemployment</font>, lack of<font color= '#66CDAA'>standard education</font>,these all may occure..
#
# # THANK YOU
# [<a href= "#Datasets-are-;-">Back To Top</a>]

# %% [markdown]
# # [Dashboard link...](https://plotly.com/~201801270001_BHARAT/39/dashboard/)
